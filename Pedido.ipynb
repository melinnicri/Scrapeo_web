# %% [markdown]
# <a href="https://colab.research.google.com/github/melinnicri/Scrapeo_web/blob/main/Pedido.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Librerías
import pandas as pd
import os

# para eliminar warning en python
import warnings
warnings.simplefilter('ignore')

# %%
# Leer el archivo CSV en un DataFrame
datos = pd.read_csv("/content/peliculas_scraped.csv")

# %%
datos.head(2)
# Out:
#                                                 href  \
# 0  https://subslikescript.com/movie/Vikingdom-178...
# 1  https://subslikescript.com/movie/LEGO_Disney_P...
#
#                                                title  \
# 0               Read transcript of Movie 'Vikingdom'
# 1  Read transcript of Movie 'LEGO Disney Princess...
#
#                                      movie_title
# 0                               Vikingdom (2013)
# 1  LEGO Disney Princess: The Castle Quest (2023)

# %%
# Pedido decía "extraiga las películas y sus correspondientes links"
# Seleccionar las columnas 'movie_title' y 'href' y crear un nuevo DataFrame
datos_seleccionados = datos[['movie_title', 'href']]
datos_seleccionados.head(2)
# Out:
#                                      movie_title  \
# 0                               Vikingdom (2013)
# 1  LEGO Disney Princess: The Castle Quest (2023)
#
#                                                 href
# 0  https://subslikescript.com/movie/Vikingdom-178...
# 1  https://subslikescript.com/movie/LEGO_Disney_P...

# %%
# Renombrar 'movie_title' a 'Título de la película' y 'href' a 'Enlace_web'
datos_seleccionados.rename(columns={'movie_title': 'Título de la película', 'href': 'Enlace_web'}, inplace=True)
datos_seleccionados.head(2)
# Out:
#                            Título de la película  \
# 0                               Vikingdom (2013)
# 1  LEGO Disney Princess: The Castle Quest (2023)
#
#                                           Enlace_web
# 0  https://subslikescript.com/movie/Vikingdom-178...
# 1  https://subslikescript.com/movie/LEGO_Disney_P...

# %%
# Guardando el DataFrame como pedido.csv
datos_seleccionados.to_csv("pedido.csv", index=False)
